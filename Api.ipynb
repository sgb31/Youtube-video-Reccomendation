# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
service_name = "youtube"#getting authentication that we can take data from youtube.(Authentication given by yooutube its by api key)
version = "v3"
api_key = "AIzaSyCslTmPeLllpDe3rmq83FvwXM5F558oKmg"
youtube = build(service_name, version, developerKey=api_key)

# %% [markdown]
# #now we can use sinppet to take data

# %%
request = youtube.search().list(#this will show the first response that we get while searching "input" in the search box
    part="snippet",
    maxResults=25,
    q=input('Enter your channel name')
)
response = request.execute()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'D_o_eEsd9Cx9MQjLR15hFOOjGE0',
#  'nextPageToken': 'CBkQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 644485, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'tOgrhrYR922azn3gUk3cjnCZRXk',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA'},
#    'snippet': {'publishedAt': '2023-06-14T07:41:42Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'Vj Siddhu Vlogs',
#     'description': 'Hello guys! Welcome to my channel! ! My channel will take you into the details of my life and give a glimpse of what inspires me to ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZPC7VuNu-GXW4lDLCW6-kKqFaCQViXgVUpB_fzaslXU-c1W3W-=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZPC7VuNu-GXW4lDLCW6-kKqFaCQViXgVUpB_fzaslXU-c1W3W-=s240-c-k-c0xffffffff-no-rj-mo'},
# ...

# %%
request = youtube.channels().list(#used to get data based on youtube channelid not by name or keyword.(channel id will be in share option)
    part="snippet,contentDetails,statistics",
    id="UC5cY198GU1MQMIPJgMkCJ_Q"
)
response = request.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'MYUtUmWWJ8VnHSqf4UNr0vTRdjA',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'EYj-aKLvN4B8BsquaWSrKBLYRTA',
#    'id': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#    'snippet': {'title': 'Mr. GK',
#     'description': 'Please contact me at mrgktamil@gmail.com\n\nFollow us on my social media:\nWhatsApp: https://whatsapp.com/channel/0029VaA23u5IHphLuhO3LM01\nYoutube: https://www.youtube.com/MrGKTamil\nFacebook: https://www.facebook.com/MrGKTamil\nTwitter: https://twitter.com/Mr_GK_Tamil\nInstagram: http://instagram.com/Mr_Gk_Tamil\nTelegram: https://t.me/MrGkGroup\n',
#     'customUrl': '@mrgktamil',
#     'publishedAt': '2017-06-15T10:15:21Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/CDiMODBTtP-gp5EJFnjwaPwioYhkPw0HLsghWllsP0BprNtQAhK0b6FqGelMasNLvVUTdWZSeg=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
# ...

# %%
request = youtube.playlists().list(#shows the playlist in there one by one if it s exist inside the channel
    part="snippet,contentDetails",
    channelId = "UC5cY198GU1MQMIPJgMkCJ_Q",
    maxResults=25
)
response = request.execute()
response
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'T7vnywXbQSN9GlH2EwDcpFQd1yE',
#  'nextPageToken': 'CBkQAA',
#  'pageInfo': {'totalResults': 42, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'dL3BoZz-WvyFPg9WxEb93UJNhrk',
#    'id': 'PLxdgXbLZbN8hg39zcevfDYeASaiJclplm',
#    'snippet': {'publishedAt': '2024-07-16T08:39:53Z',
#     'channelId': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#     'title': 'Sciwich',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lYrnG_mq91Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lYrnG_mq91Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lYrnG_mq91Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lYrnG_mq91Q/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
request = youtube.playlistItems().list(
  part="snippet,contentDetails",
  maxResults=25,
  playlistId="PLxdgXbLZbN8jpnvkDZcajRKphxzgIRjpe"
)
response = request.execute()
response
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'Tu8Z3Aaouyj8gWBRg1xDqLXQK5Q',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'lHpUMVEax7i8BDFJDL01CmkjsNg',
#    'id': 'UEx4ZGdYYkxaYk44anBudmtEWmNhalJLcGh4emdJUmpwZS41NkI0NEY2RDEwNTU3Q0M2',
#    'snippet': {'publishedAt': '2021-10-20T06:02:11Z',
#     'channelId': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#     'title': '10 Most Weird Animals on the Earth | Mr.GK',
#     'description': 'Facebook: https://www.facebook.com/MrGKTamil\nTwitter: https://twitter.com/Mr_GK_Tamil\nInstagram: http://instagram.com/Mr_Gk_Tamil\nTelegram: https://telegram.me/MrGkGroup\n\n0:00 - Total Species on the Earth\n1:22 - Axolotl\n2:12 - Glass frogs\n2:42 - Lyrebird\n4:02 - Leafy Sea Dragon\n4:57 - Pacu fish\n5:43 - Sparklemuffin\n6:26 - Blobfish\n7:20 - Treehoppers\n8:00 - Poodle moth\n9:21 - Platypus\n10:33 - Bonus - Blue-footed booby\n\n#MrGK\n#WowFacts\n#UnknownFacts\n\nMr.GK stands for Mr.General Knowledge.',
# ...

# %%
request = youtube.videos().list(#education data list and its output
    part = "snippet,contentDetails,statistics",
    id = "ZTt9gsGcdDo,aMJt1OGzjpM,aA76uj5kQac,l5azMXvBfaw,DxL2HoqLbyA"
)
eduresponse = request.execute()

# %%
eduresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'Km3GbKPT0wR-wRoMymBNmAtRUKU',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'zIHd24yourjDFXmNCkS_xK4vZAo',
#    'id': 'ZTt9gsGcdDo',
#    'snippet': {'publishedAt': '2023-12-11T05:00:25Z',
#     'channelId': 'UCtYLUTtgS3k1Fg4y5tAhLbw',
#     'title': 'Essential Matrix Algebra for Neural Networks, Clearly Explained!!!',
# ...

# %%
request = youtube.videos().list(#fitness data list and its output
    part = "snippet,contentDetails,statistics",
    id = "lumSzWAthsg,DjfnFj-50b4,zLP00blhzvM,wsFd0LoIyKk,ufrFCjERMDc"
)
fitresponse = request.execute()

# %%
fitresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '2pDVUlpogshB8Z9UznkT63ZaSV4',
#  'items': [{'kind': 'youtube#video',
#    'etag': '-1e9HBcVT_Kk0GupaQXvr4b-FIo',
#    'id': 'lumSzWAthsg',
#    'snippet': {'publishedAt': '2024-05-27T16:00:38Z',
#     'channelId': 'UCly3G2YO3O0Bu3IA8c6WiqQ',
#     'title': 'Ronnie Coleman TRAINS with AMERICAS TOP Police Officers',
# ...

# %%
request = youtube.videos().list(#music data list and its output
    part = "snippet,contentDetails,statistics",
    id = "ZGdLMEka6dc,b1aBzAE-IFY,AA75gCdr2TM,sJ2epzhNL_A,_lpSCOZ1PCo"
)
musresponse = request.execute()

# %%
musresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'B53jPZondU6pFo7RJIzsH-uYkwQ',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'Q6cpNiilGLZ_UL2DF_kmZHX3ET8',
#    'id': 'ZGdLMEka6dc',
#    'snippet': {'publishedAt': '2024-08-06T04:00:00Z',
#     'channelId': 'UC0WP5P-ufpRfjbNrmOWwLBQ',
#     'title': 'Unprepared certainty…',
#     'description': 'Directed & Edited by Evan Larsen\nProduction Company: Studio Sands & Blue\nCow Studios\nProducers: Ryan Kincade & Will Harbert\nVFX & Animation: Evan Larsen\nSmoke Sim: Zeke Wagner\n3D Modeling: Futhark Studios & Blue Cow\nStudios\nCharacter Creation: Prime Polygon & Blue\nCow Studios\nColorist: Cameron Marygold',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZGdLMEka6dc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZGdLMEka6dc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
request = youtube.videos().list(#news data list and its output
    part = "snippet,contentDetails,statistics",
    id = "1E6YHpjwvmw,0V46nzHCcbc,_-3yO2KYIJ8,hGjkcGnZazo,-EFpCzAEfbs"
)
newsresponse = request.execute()

# %%
newsresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'sEhGfFpfA6uwxjg8tVlFYsUr4_Q',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'eRfx8XN-ZgrlTwpqj-5HVb-NIQU',
#    'id': '1E6YHpjwvmw',
#    'snippet': {'publishedAt': '2024-08-07T23:44:53Z',
#     'channelId': 'UCupvZG-5ko_eiXAupbDfxWw',
#     'title': 'Trump escalates attacks on Walz',
#     'description': "CNN's Jeff Zeleny breaks down the latest from the campaign trail, where eyes, including former President Donald Trump's, are on Vice President Kamala Harris' new running mate, Minnesota Governor Tim Walz. Erica Hill and her panel of experts discuss. #CNN #news \n\nWant to stay up to date on the day’s top stories? Sign up for CNN’s 5 Things newsletter, and we’ll give you the 5 biggest stories you need to know, videos people are watching, and more!\n\nSign up here: https://www.cnn.com/newsletters/5-things?source=nl-acq_social_youtubedesc&utm_source=nl-acq_social_youtubedesc",
# ...

# %%
request = youtube.videos().list(#food data list and its output
    part = "snippet,contentDetails,statistics",
    id = "3UPVfQ3qQCE,QTXjUAzZiQM,iViFbBbvENU,T4NOt727wqI,DFjkHnZCqmU"
)
foodresponse = request.execute()

# %%
foodresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'FMYUYGDQkUd3ahc6UB337DuIxAM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'X_OigMji101jB0BNcQPhRRAMobk',
#    'id': '3UPVfQ3qQCE',
#    'snippet': {'publishedAt': '2024-07-04T14:05:32Z',
#     'channelId': 'UCk3JZr7eS3pg5AGEvBdEvFg',
#     'title': 'CHILLI GARLIC FRIED CHICKEN | Cooking and Eating in Village | Spicy Chicken Recipe | Chicken Starter',
#     'description': 'Today, in our village, we cook a spicy chicken recipe using Chili, Garlic, and sauces. First, we fry marinated chicken and mix it with some veggies and sauces in an open vessel. This chicken recipe is best for starters, and it will be delicious with a slight spiciness.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3UPVfQ3qQCE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3UPVfQ3qQCE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
request = youtube.videos().list(#travel data list and its output
    part = "snippet,contentDetails,statistics",
    id = "W4nKWBcICyQ,Uhydkk9h1sA,YlD_4OV0VKk,IuTDuvYr7f0,QVoSgRbd69c"
)
travelresponse = request.execute()

# %%
travelresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'dZFeXWetSqIGJzQBj8x2Uewh5zs',
#  'items': [{'kind': 'youtube#video',
#    'etag': '_JwNLNf9HGQ3fdSi55s735nQ_YE',
#    'id': 'W4nKWBcICyQ',
#    'snippet': {'publishedAt': '2024-08-06T14:01:45Z',
#     'channelId': 'UCDnq05Q89oYq-Tz5boL73Tw',
#     'title': 'Bhutan 10 Day Itinerary: Festivals, Off Beat Wonders & Cultural Secrets |One World Ep4 | Curly Tales',
# ...

# %%
request = youtube.videos().list(#Fashion data list and its output
    part = "snippet,contentDetails,statistics",
    id = "yycVNcishrE,M8v5wU5Xa3A,65_PhFSYLRg,klKVm1FALhs,XSF9AOx7sdU"
)
fashionresponse = request.execute()

# %%
fashionresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'umqiEnWQxQaAN9QXT74xwDWNChg',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'G_wsqViSMJZiNQDpyy4BiBP_DYA',
#    'id': 'yycVNcishrE',
#    'snippet': {'publishedAt': '2023-08-10T22:00:07Z',
#     'channelId': 'UCyTS-kqntjFL_qxt9orBytg',
#     'title': 'Britney Manson - FΛSHION (Single, 2023)',
#     'description': 'TRANS TIK-TOK SENSATION, MODEL AND ARTIST BRITNEY MANSON RELEASES LATEST SINGLE: https://orcd.co/bm_fashion\n\nBritney Manson releases "Fashion" to inspire her fans to imagine themselves as their own It Girl.\n\nBritney Manson in social media:\nhttps://instagram.com/britneymnsn\nhttps://www.tiktok.com/@britneymnsn\nhttps://britneymanson.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yycVNcishrE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yycVNcishrE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
request = youtube.videos().list(#motivation data list and its output
    part = "snippet,contentDetails,statistics",
    id = "wnHW6o8WMas,JjvN_hYDp3g,Tuw8hxrFBH8,tbnzAVRZ9Xc,svDiqqnGCeU"
)
motivationresponse = request.execute()

# %%
motivationresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'xH15jkCBrCdrv9PFRsmyDdP5IwA',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'eVx1lolW4F6lopus9ZEPfzB9OlQ',
#    'id': 'wnHW6o8WMas',
#    'snippet': {'publishedAt': '2018-06-11T01:54:41Z',
#     'channelId': 'UCgkKA7xEOoBQNpC5TJxPLiw',
#     'title': 'NO EXCUSES - Best Motivational Video',
# ...

# %%
request = youtube.videos().list(#finance data list and its output
    part = "snippet,contentDetails,statistics",
    id = "BVNxSRpuAts,glfX6mwosaI,BTOHpoC-XsE,WN9Mks1s4tM,BOPg2AgjvNA"
)
financeresponse = request.execute()

# %%
financeresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'c-Rae5GPyIRjIUQZZrxB6sC1TCc',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'xT2ybrAyr5T2yaMLy470G5YWHwQ',
#    'id': 'BVNxSRpuAts',
#    'snippet': {'publishedAt': '2024-07-24T12:31:35Z',
#     'channelId': 'UCwVEhEzsjLym_u1he4XWFkg',
#     'title': 'How To Achieve 8.7 Crores In 15 Years?',
# ...

# %%
request = youtube.videos().list(#reviews data list and its output
    part = "snippet,contentDetails,statistics",
    id = "iExBIgHyMrw,KBaWrj5lR98,byYkBS_hsdU,kzp4bSCsloc,kUrT2UErII8"
)
reviewsresponse = request.execute()

# %%
reviewsresponse['items']
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'fmuwDSSWDwBr7Lzuiet8p-AkhoM',
#   'id': 'iExBIgHyMrw',
#   'snippet': {'publishedAt': '2024-08-02T16:00:52Z',
#    'channelId': 'UCCqEeDAUf4Mg0GgEN658tkA',
#    'title': 'Trap - Movie Review',
#    'description': 'Chris Stuckmann reviews Trap, starring Josh Hartnett, Ariel Donoghue, Alison Pill, Hayley Mills, Saleka Shyamalan, Kid Cudi. Directed by M. Night Shyamalan.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iExBIgHyMrw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iExBIgHyMrw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iExBIgHyMrw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/iExBIgHyMrw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/iExBIgHyMrw/maxresdefault.jpg',
# ...

# %%
import json

# %%
reviewsresponse.to_json('reviewsresponse.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 reviewsresponse.to_json('reviewsresponse.json')
#
# AttributeError: 'dict' object has no attribute 'to_json'

# %%
with open('reviewsresponse.json', 'w') as json_file:
    json.dump(reviewsresponse, json_file, indent=4)

# %%
print(type(reviewsresponse))
# Out:
# <class 'dict'>

# %%
with open('travelresponse.json', 'w') as json_file:
    json.dump(travelresponse, json_file, indent=4)

# %%
with open('foodresponse.json', 'w') as json_file:
    json.dump(foodresponse, json_file, indent=4)

# %%
with open('fashionresponse.json', 'w') as json_file:
    json.dump(fashionresponse, json_file, indent=4)

# %%
with open('eduresponse.json', 'w') as json_file:
    json.dump(eduresponse, json_file, indent=4)

# %%
with open('fitresponse.json', 'w') as json_file:
    json.dump(fitresponse, json_file, indent=4)

# %%
with open('musresponse.json', 'w') as json_file:
    json.dump(musresponse, json_file, indent=4)

# %%
with open('motivationresponse.json', 'w') as json_file:
    json.dump(motivationresponse, json_file, indent=4)

# %%
with open('financeresponse.json', 'w') as json_file:
    json.dump(financeresponse, json_file, indent=4)

# %%
with open('newsresponse.json', 'w') as json_file:
    json.dump(newsresponse, json_file, indent=4)

# %%
import pandas as pd

# %%
reviews=pd.json_normalize(reviewsresponse['items'])

# %%
reviews=pd.set_option('display.max_columns',None)

# %%
reviews
# Out:
#             kind                         etag           id  \
# 0  youtube#video  fmuwDSSWDwBr7Lzuiet8p-AkhoM  iExBIgHyMrw
# 1  youtube#video  Y7FcQ_f6AsyV1azoNbQlC8PwR4A  KBaWrj5lR98
# 2  youtube#video  wXuYYgcrBHS4mskpzxoPXGQgG9g  byYkBS_hsdU
# 3  youtube#video  MYvGC1oP32WetH5s97_mOhDdo50  kzp4bSCsloc
# 4  youtube#video  XL1awQfvmTDAra5PASwhWjk1vXw  kUrT2UErII8
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2024-08-02T16:00:52Z  UCCqEeDAUf4Mg0GgEN658tkA
# 1  2024-08-08T07:00:02Z  UCnHKPjNJ5ZhU0flwK4tTeBA
# 2  2024-08-05T14:09:02Z  UCtgJ5CpSHgfqbFtkoEtcBtQ
# 3  2024-07-26T13:00:54Z  UC7v3-2K1N84V67IF-WTRG-Q
# 4  2024-08-01T18:00:24Z  UC9Kq-yEt1iYsbUzNOoIRK0g
#
#                                        snippet.title  \
# 0                                Trap - Movie Review
# 1                         Borderlands - Movie Review
# 2  The Old Way Full Movie In English Review | Nic...
# 3                Deadpool & Wolverine - Movie Review
# ...

# %%
reviews['snippet.tags']
# Out:
# 0    [Trap, Movie Review, Chris Stuckmann, 2024, Re...
# 1    [borderlands, borderlands movie, borderlands r...
# 2                                                  NaN
# 3    [deadpool, deadpool and wolverine, deadpool 3,...
# 4    [Deadpool & Wolverine, blade, cameos, channing...
# Name: snippet.tags, dtype: object

# %%
reviews['snippet.tags'][0]
# Out:
# ['Trap',
#  'Movie Review',
#  'Chris Stuckmann',
#  '2024',
#  'Reviews',
#  'Film',
#  'Scene',
#  'Concert',
#  'Thriller',
#  'Josh Hartnett',
#  'Ariel Donoghue',
#  'Alison Pill',
#  'Hayley Mills',
#  'Saleka Shyamalan',
#  'Kid Cudi',
#  'Trailer',
#  'Teaser',
#  'M. Night Shyamalan']

# %%
import numpy
import gensim
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[366], line 2
#       1 import numpy
# ----> 2 import gensim
#
# File ~/Desktop/Youtube/.venv/lib/python3.12/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~/Desktop/Youtube/.venv/lib/python3.12/site-packages/gensim/corpora/__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
# ...

# %%
reviews['snippet.tags'].apply(gensim.utils.simple_preprocess())

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(reviews)

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(X)

# Get the top tags for each cluster
top_tags = []
for i in range(5):
    cluster_tags = X[kmeans.labels_ == i].sum(axis=0).argsort()[-10:]
    top_tags.append([vectorizer.get_feature_names_out()[j] for j in cluster_tags])

# User input
user_input = input("enter the name:")
user_vector = vectorizer.transform([user_input])

# Predict the cluster for the user input
cluster = kmeans.predict(user_vector)[0]

# Output the top tags for the predicted cluster
print(top_tags[cluster])
# Out:
# Python(564) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(583) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [array([['width', 'maxres', 'localized', 'livebroadcastcontent',
#         'likecount', 'snippet', 'standard', 'viewcount', 'high',
#         'height', 'favoritecount', 'statistics', 'tags', 'thumbnails',
#         'description', 'title', 'defaultlanguage',
#         'defaultaudiolanguage', 'default', 'url', 'commentcount',
#         'channeltitle', 'channelid', 'categoryid', 'medium',
#         'publishedat', 'caption', 'licensedcontent', 'kind', 'etag',
#         'duration', 'dimension', 'definition', 'projection', 'id',
#         'contentdetails']], dtype=object)]

# %%
reviews
# Out:
#             kind                         etag           id  \
# 0  youtube#video  nvfCNFCJeL2iA2N2ewMlIyVpB0E  iExBIgHyMrw
# 1  youtube#video  wazjCGEHNbSSLU1ZJ4od0H90UIc  KBaWrj5lR98
# 2  youtube#video  tekuGFqsFwXqQv1q10s26tDaujw  byYkBS_hsdU
# 3  youtube#video  aIZt_5O3qsV4Zy0kQJECFRBsGLE  kzp4bSCsloc
# 4  youtube#video  P--npfFIsP_OXefuK-wieLefvFQ  kUrT2UErII8
#
#                                              snippet  \
# 0  {'publishedAt': '2024-08-02T16:00:52Z', 'chann...
# 1  {'publishedAt': '2024-08-08T07:00:02Z', 'chann...
# 2  {'publishedAt': '2024-08-05T14:09:02Z', 'chann...
# 3  {'publishedAt': '2024-07-26T13:00:54Z', 'chann...
# 4  {'publishedAt': '2024-08-01T18:00:24Z', 'chann...
#
#                                       contentDetails  \
# 0  {'duration': 'PT6M57S', 'dimension': '2d', 'de...
# 1  {'duration': 'PT9M35S', 'dimension': '2d', 'de...
# 2  {'duration': 'PT1H40M24S', 'dimension': '2d', ...
# 3  {'duration': 'PT7M21S', 'dimension': '2d', 'de...
# ...

# %%
reviewss=pd.DataFrame(reviews['snippet'])

# %%
reviewsss=pd.DataFrame(reviews['contentDetails'])

# %%
jsonreviews=pd.json_normalize(reviewss)

# %%
print(json_normalize)
# Out:
# <function json_normalize at 0x10a63ef20>

# %%
reviewsss
# Out:
#                                       contentDetails
# 0  {'duration': 'PT6M57S', 'dimension': '2d', 'de...
# 1  {'duration': 'PT9M35S', 'dimension': '2d', 'de...
# 2  {'duration': 'PT1H40M24S', 'dimension': '2d', ...
# 3  {'duration': 'PT7M21S', 'dimension': '2d', 'de...
# 4  {'duration': 'PT6M18S', 'dimension': '2d', 'de...
